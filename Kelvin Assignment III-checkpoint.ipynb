# %%
#Importing the necessary Tools
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly
import plotly.express as px
import plotly.graph_objs as go

# %%
#Importing the Data
IBMData=pd.read_csv(r'C:\Users\ADMIN\Desktop\ADS Folder\ADS Assignments\WA_Fn-UseC_-HR-Employee-Attrition.csv')
IBMData.head()
# Out:
#    Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41       Yes  Travel_Rarely       1102      Sales                 1
# 1   53        No  Travel_Rarely       1219      Sales                 2
# 2   36       Yes  Travel_Rarely       1218      Sales                 9
# 3   42        No  Travel_Rarely        691      Sales                 8
# 4   46        No  Travel_Rarely        705      Sales                 2
#
#    Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2  Life Sciences              1               1  ...
# 1          4  Life Sciences              1              23  ...
# 2          4  Life Sciences              1              27  ...
# 3          4      Marketing              1              35  ...
# 4          4      Marketing              1              38  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0                         1            80                 0
# ...

# %%
#Analysis of distance from home by job role and attrition.
Analysis1= IBMData.groupby(["JobRole","Attrition"])["DistanceFromHome"].mean().unstack().fillna(0)
Analysis1
# Out:
# Attrition                        No        Yes
# JobRole
# Healthcare Representative  9.204918  17.666667
# Human Resources            6.600000  13.416667
# Laboratory Technician      9.329949   9.661290
# Manager                    7.927835  10.000000
# Manufacturing Director     9.533333   8.800000
# Research Director          8.474359   7.000000
# Research Scientist         8.869388   9.765957
# Sales Executive            9.026022  12.649123
# Sales Representative       9.000000   8.151515

# %%
#Generating Bar plot for the above
Analysis1.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='JobRole'>

# %%
#Comparison of Average Monthly income vs Education and Attrition
Analysis2=IBMData.groupby(["Education", "Attrition"])["MonthlyIncome"].mean().unstack().fillna(0)
Analysis2
# Out:
# Attrition           No          Yes
# Education
# 1          5926.129496  4360.161290
# 2          6586.058824  4282.545455
# 3          6882.919662  4770.242424
# 4          7087.814706  5335.155172
# 5          8559.906977  5850.200000

# %%
#Generating a Bar Plot of the above analysis
Analysis2.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Education'>
