# %% [markdown]
# # Analysis of IBM Attrition

# %%
#First we import the necessary tools for analysis and plotting
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly
import plotly.express as px
import plotly.graph_objs as go

# %%
#Importing our data for analysis
df=pd.read_csv(r"C:\Users\ADMIN\Desktop\ADS Folder\ADS Assignments\WA_Fn-UseC_-HR-Employee-Attrition.csv")
df.head()
# Out:
#    Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41       Yes  Travel_Rarely       1102      Sales                 1
# 1   53        No  Travel_Rarely       1219      Sales                 2
# 2   36       Yes  Travel_Rarely       1218      Sales                 9
# 3   42        No  Travel_Rarely        691      Sales                 8
# 4   46        No  Travel_Rarely        705      Sales                 2
#
#    Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2  Life Sciences              1               1  ...
# 1          4  Life Sciences              1              23  ...
# 2          4  Life Sciences              1              27  ...
# 3          4      Marketing              1              35  ...
# 4          4      Marketing              1              38  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0                         1            80                 0
# ...

# %%
#Understanding our data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#checking missing values in the data
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#converting our dependent variable(Attrition) to binary numeric variable
df['Attrition'].replace(to_replace='Yes', value=1, inplace=True)


df['Attrition'].replace(to_replace='No',  value=0, inplace=True)

# %%
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#For question 1 and 2 data require is only distance from home,job role, monthly income, education and ofcourse ATTRITION
#Dropping unnecessary data and naming our data as df2
df2=df[["Attrition","DistanceFromHome", "JobRole", "MonthlyIncome", "Education"]]
df2.head()
# Out:
#    Attrition  DistanceFromHome                JobRole  MonthlyIncome  \
# 0          1                 1        Sales Executive           5993
# 1          0                 8     Research Scientist           5130
# 2          1                 2  Laboratory Technician           2090
# 3          0                 3     Research Scientist           2909
# 4          0                 2  Laboratory Technician           3468
#
#    Education
# 0          2
# 1          1
# 2          2
# 3          4
# 4          1

# %% [markdown]
# # For question One, lets define our DataFrame
# #Of course Attrition becomes our dependent variable, Distance from Home is our Independent Variable

# %%
#Data description
df.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810     0.161224   802.485714          9.192517     2.912925
# std       9.135373     0.367863   403.509100          8.106864     1.024165
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     0.000000   465.000000          2.000000     2.000000
# 50%      36.000000     0.000000   802.000000          7.000000     3.000000
# 75%      43.000000     0.000000  1157.000000         14.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769    65.891156
# ...

# %%
df3=df[["Attrition","DistanceFromHome","JobRole"]]
df3
# Out:
#       Attrition  DistanceFromHome                    JobRole
# 0             1                 1            Sales Executive
# 1             0                 8         Research Scientist
# 2             1                 2      Laboratory Technician
# 3             0                 3         Research Scientist
# 4             0                 2      Laboratory Technician
# ...         ...               ...                        ...
# 1465          0                23      Laboratory Technician
# 1466          0                 6  Healthcare Representative
# 1467          0                 4     Manufacturing Director
# 1468          0                 2            Sales Executive
# 1469          0                 8      Laboratory Technician
#
# [1470 rows x 3 columns]

# %%
#Average DistanceFromHome for all JobRoles
df[["DistanceFromHome", "JobRole"]].groupby("JobRole").mean()
# Out:
#                            DistanceFromHome
# JobRole
# Healthcare Representative          9.786260
# Human Resources                    8.173077
# Laboratory Technician              9.409266
# Manager                            8.029412
# Manufacturing Director             9.482759
# Research Director                  8.437500
# Research Scientist                 9.013699
# Sales Executive                    9.659509
# Sales Representative               8.662651

# %%
#To show the Avg DistancefromHome for all JobRoles and their Attriction Status

df.groupby(["JobRole", "Attrition"])["DistanceFromHome"].mean()
# Out:
# JobRole                    Attrition
# Healthcare Representative  0             9.204918
#                            1            17.666667
# Human Resources            0             6.600000
#                            1            13.416667
# Laboratory Technician      0             9.329949
#                            1             9.661290
# Manager                    0             7.927835
#                            1            10.000000
# Manufacturing Director     0             9.533333
#                            1             8.800000
# Research Director          0             8.474359
#                            1             7.000000
# Research Scientist         0             8.869388
#                            1             9.765957
# Sales Executive            0             9.026022
#                            1            12.649123
# Sales Representative       0             9.000000
#                            1             8.151515
# ...

# %%
#Comparing Average Monthly Income by Education and Attrition
df.groupby(["Education", "Attrition"])["MonthlyIncome"].mean().unstack().fillna(0)
# Out:
# Attrition           No          Yes
# Education
# 1          5926.129496  4360.161290
# 2          6586.058824  4282.545455
# 3          6882.919662  4770.242424
# 4          7087.814706  5335.155172
# 5          8559.906977  5850.200000
